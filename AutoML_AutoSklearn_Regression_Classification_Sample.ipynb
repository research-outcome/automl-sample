# %% [markdown]
# ## AutoSklearn AutoML Sample Code

# %%
# !pip install auto-sklearn
# !pip install numpy --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 67.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 76.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 83.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 76.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.9/260.9 kB 27.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# ### ***If you get error for the following, try restating the kernel***

# %%
from sklearn import metrics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Regression

# %% [markdown]
# #### Load Data

# %%
cars = pd.read_csv('cars.csv')

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38531 entries, 0 to 38530
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   manufacturer_name  38531 non-null  object
#  1   model_name         38531 non-null  object
#  2   transmission       38531 non-null  object
#  3   color              38531 non-null  object
#  4   odometer_value     38531 non-null  int64
#  5   year_produced      38531 non-null  int64
#  6   engine_fuel        38531 non-null  object
#  7   engine_has_gas     38531 non-null  bool
#  8   engine_type        38531 non-null  object
#  9   engine_capacity    38521 non-null  float64
#  10  body_type          38531 non-null  object
#  11  has_warranty       38531 non-null  bool
#  12  state              38531 non-null  object
#  13  drivetrain         38531 non-null  object
#  14  price_usd          38531 non-null  float64
#  15  is_exchangeable    38531 non-null  bool
# ...

# %%
label = 'price_usd'

# %%
# Split the data to test and train
from sklearn.model_selection import train_test_split
cars_train, cars_test = train_test_split(cars, test_size=0.2, random_state=42)
cars_test_labels = cars_test[label]
cars_test_nolabel = cars_test.drop([label], axis=1)
cars_train_labels = cars_train[label]
cars_train_nolabel = cars_train.drop([label], axis=1)
cars_train.head()
# Out:
#       manufacturer_name      model_name transmission   color  odometer_value  \
# 37935           Peugeot             307   mechanical  silver          320000
# 28568               BMW             525    automatic  violet          400000
# 24311         Chevrolet         Captiva   mechanical    grey           79000
# 19393              Jeep  Grand Cherokee    automatic   other          500000
# 2540               Opel           Astra   mechanical  silver          280000
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 37935           2005    gasoline           False    gasoline              1.6
# 28568           1997      diesel           False      diesel              2.5
# 24311           2015      diesel           False      diesel              2.2
# 19393           2004      diesel           False      diesel              2.7
# 2540            2007      diesel           False      diesel              1.7
#
# ...

# %%
cars_train.head()
# Out:
#       manufacturer_name      model_name transmission   color  odometer_value  \
# 37935           Peugeot             307   mechanical  silver          320000
# 28568               BMW             525    automatic  violet          400000
# 24311         Chevrolet         Captiva   mechanical    grey           79000
# 19393              Jeep  Grand Cherokee    automatic   other          500000
# 2540               Opel           Astra   mechanical  silver          280000
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 37935           2005    gasoline           False    gasoline              1.6
# 28568           1997      diesel           False      diesel              2.5
# 24311           2015      diesel           False      diesel              2.2
# 19393           2004      diesel           False      diesel              2.7
# 2540            2007      diesel           False      diesel              1.7
#
# ...

# %%
import autosklearn.regression

regression = autosklearn.regression.AutoSklearnRegressor(time_left_for_this_task=5*60,
                                                              per_run_time_limit=30, 
                                                              n_jobs=8)

# %%
# perform the search for cars 
regression.fit(cars_train_nolabel, cars_train_labels)
# Out:
# /usr/local/lib/python3.10/dist-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column manufacturer_name has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column model_name has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column transmission has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# ...

# %%
import sklearn

# %%
#Predict using the model¶
predictions = regression.predict(cars_test_nolabel)
print("Accuracy score:{}".format(sklearn.metrics.mean_absolute_error(cars_test_labels, predictions)))
# Out:
# Accuracy score:6383.97175662547

# %%
print(regression.sprint_statistics())
# Out:
# auto-sklearn results:
#   Dataset name: a1bead31-0787-11ee-8be6-0242ac1c000c
#   Metric: r2
#   Number of target algorithm runs: 89
#   Number of successful target algorithm runs: 0
#   Number of crashed target algorithm runs: 89
#   Number of target algorithms that exceeded the time limit: 0
#   Number of target algorithms that exceeded the memory limit: 0

# %%
regression.leaderboard()
# Out:
#           rank  ensemble_weight  type  cost duration
# model_id
# 1            1              1.0  <NA>  <NA>     <NA>

# %%
print(regression.show_models)
# Out:
# <bound method AutoSklearnEstimator.show_models of AutoSklearnRegressor(ensemble_class=<class 'autosklearn.ensembles.ensemble_selection.EnsembleSelection'>,
#                      n_jobs=8, per_run_time_limit=30,
#                      time_left_for_this_task=300)>

# %% [markdown]
# ### Classification

# %% [markdown]
# ##### Load Data

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Define the label column
label = 'Survived'

# %%
# Split the data to test and train
from sklearn.model_selection import train_test_split
titanic_train, titanic_test = train_test_split(titanic, test_size=0.2, random_state=42)
titanic_test_labels = titanic_test[label]
titanic_test_nolabel = titanic_test.drop([label], axis=1)
titanic_train_labels = titanic_train[label]
titanic_train_nolabel = titanic_train.drop([label], axis=1)
titanic_train.head()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 331          332         0       1                 Partner, Mr. Austen
# 733          734         0       2          Berriman, Mr. William John
# 382          383         0       3                  Tikkanen, Mr. Juho
# 704          705         0       3             Hansen, Mr. Henrik Juul
# 813          814         0       3  Andersson, Miss. Ebba Iris Alfrida
#
#         Sex   Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 331    male  45.5      0      0             113043  28.5000  C124        S
# 733    male  23.0      0      0              28425  13.0000   NaN        S
# 382    male  32.0      0      0  STON/O 2. 3101293   7.9250   NaN        S
# 704    male  26.0      1      0             350025   7.8542   NaN        S
# 813  female   6.0      4      2             347082  31.2750   NaN        S

# %%
titanic_train.head()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 331          332         0       1                 Partner, Mr. Austen
# 733          734         0       2          Berriman, Mr. William John
# 382          383         0       3                  Tikkanen, Mr. Juho
# 704          705         0       3             Hansen, Mr. Henrik Juul
# 813          814         0       3  Andersson, Miss. Ebba Iris Alfrida
#
#         Sex   Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 331    male  45.5      0      0             113043  28.5000  C124        S
# 733    male  23.0      0      0              28425  13.0000   NaN        S
# 382    male  32.0      0      0  STON/O 2. 3101293   7.9250   NaN        S
# 704    male  26.0      1      0             350025   7.8542   NaN        S
# 813  female   6.0      4      2             347082  31.2750   NaN        S

# %%
import autosklearn.classification

classification = autosklearn.classification.AutoSklearnClassifier(time_left_for_this_task=5*60, 
                                                                 per_run_time_limit=30,
                                                                 n_jobs=8)

# %%
#perform it 
classification.fit(titanic_train_nolabel, titanic_train_labels)
# Out:
# /usr/local/lib/python3.10/dist-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Name has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Sex has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Ticket has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# ...

# %%
#Predict using the model¶
predictions = classification.predict(titanic_test_nolabel)
print("Accuracy score:{}".format(sklearn.metrics.accuracy_score(titanic_test_labels, predictions)))
# Out:
# Accuracy score:0.8100558659217877

# %%
#statistics 
print(classification.sprint_statistics())
# Out:
# auto-sklearn results:
#   Dataset name: 93da2151-0788-11ee-8be6-0242ac1c000c
#   Metric: accuracy
#   Best validation score: 0.829787
#   Number of target algorithm runs: 58
#   Number of successful target algorithm runs: 31
#   Number of crashed target algorithm runs: 22
#   Number of target algorithms that exceeded the time limit: 5
#   Number of target algorithms that exceeded the memory limit: 0
